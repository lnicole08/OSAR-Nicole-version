# %%
#import relevant libraries
#Load modules
import os
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import seaborn as sbs
import dabest
from datetime import datetime
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
from tqdm import tqdm
from time import sleep
import plotly.graph_objects as go
from scipy.signal import find_peaks
from numpy import genfromtxt
from scipy import fftpack
import scipy.stats as stats
import scipy 
from struct import *
import math
import osar
import sys
import glob
import scipy as sp
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import re
import warnings
date = datetime.today().strftime('%Y%m%d')

warnings.simplefilter(action="ignore", category=RuntimeWarning)
warnings.simplefilter(action="ignore", category=FutureWarning)
#warnings.simplefilter(action="default", category=RuntimeWarning)
# Out:
# Pre-compiling numba functions for DABEST...
# Compiling numba functions: 100%|██████████| 11/11 [00:00<00:00, 22.97it/s]
# Numba compilation complete!

# %%
 #SHOULD USE to generate specific genotype
officecomp = "C:\\Users\\Star\\"
labcomp = "C:\\Users\\User\\"
computer2 = "C:\\Users\\lnico\\"
homecomp = "D:\\"
specifiedpath = homecomp

root = specifiedpath + "ACC Lab Dropbox\\ACC Lab\\Nicole Lee\\DATA\\OSAR\\"

# %%
#single or list of files
startdir = ["SS86947 x ACR", "SS01298 x ACR", "SS77474 x Chrimson2", "SS01038 x Chrimson2", "SS80896 x Chrimson2", "SS80958 x Chrimson2"]

baseDirectory=[]
basegenotype=[]
for n,sd in enumerate(startdir):
    dir1 = os.path.join(root, sd)
    baseDirectory.append(dir1)
    print(dir1)
    basegenotype.append(re.search(r'^.*?(?= x )', (os.path.split(dir1)[1])).group(0))
    #basegenotype.append(re.search(r'^.*?(?=-Gal4)', (os.path.split(dir1)[1])).group(0))
# Out:
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\SS86947 x ACR
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\SS01298 x ACR
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\SS77474 x Chrimson2
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\SS01038 x Chrimson2
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\SS80896 x Chrimson2
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\SS80958 x Chrimson2

# %%
# all files at once (ONLY IF U PLAN TO RUN ALL AT ONCE)
startdir = os.listdir(root)
files_with_x = [f for f in startdir if 'x' in f]

baseDirectory=[]
basegenotype=[]
for n,sd in enumerate(files_with_x):
    dir1 = os.path.join(root, files_with_x[n])
    baseDirectory.append(dir1)
    print(dir1)
    basegenotype.append(re.search(r'^.*?(?= x )', (os.path.split(dir1)[1])).group(0))
    #basegenotype.append(re.search(r'^.*?(?=-Gal4)', (os.path.split(dir1)[1])).group(0))

# %%
for loc,name in zip(baseDirectory,basegenotype):
    df = osar.osar(loc,driver = name).results
    transgenicname = loc.split("\\")[-1]
    filepath = specifiedpath + "ACC Lab Dropbox\\ACC Lab\\Nicole Lee\\Data Compilation\\osar_compiled\\2025collection\\" + transgenicname + ".csv"
    df.to_csv(filepath)
    print(name)
# Out:
# Creating borders for each fly...
# Done.
#
# Processing CSV 1 of 40
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 for loc,name in zip(baseDirectory,basegenotype):
# ----> 2     df = osar.osar(loc,driver = name).results
#       3     transgenicname = loc.split("\\")[-1]
#       4     filepath = specifiedpath + "ACC Lab Dropbox\\ACC Lab\\Nicole Lee\\Data Compilation\\osar_compiled\\2025collection\\" + transgenicname + ".csv"
#
# File c:\Users\user\anaconda3\envs\20250930version\lib\site-packages\osar\osar.py:182, in osar.__init__(self, path_to_data, driver, countlog_folder, border_folder, framerate_fps, rolling_average_window_seconds, traversal_time_window_seconds, choicezone_width_mm, light_on_time_start, light_off_time_start, border_shift_mm)
#     176 self.borders.loc[idxx[:,['Pattern 10']],
#     177                   idxx["midzone2"]] = p10_mz2 - bshift_pixels
#     180 print('Done.\n')
#     181 self.flies, self.tracks, \
# --> 182         self.results, self.weird_flies = munger.process_countlogs(
#     183                                           self.borders,
#     184                                           driver,
#     185                                           path_to_data,
#     186                                           countlog_folder,
#     187                                           self.TRAVERSAL_WINDOW_IDX,
#     188                                           self.LIGHT_ON_TIME_START,
#     189                                           self.LIGHT_OFF_TIME_START,
#     190                                           self.PIXEL_LENGTH_MM,
#     191                                           self.CHOICEZONE_WIDTH_MM,
#     192                                           self.WINDOW_SIZE,
#     193                                           self.ZONE_WIDTH)
#     195 self.metrics = self.results.columns.tolist()[8:]
#     197 # Comment these two lines below during development of either plot.
#     198 # Passes an instance of `self` to plotter.
#
# File c:\Users\user\anaconda3\envs\20250930version\lib\site-packages\osar\munger\munger.py:1042, in process_countlogs(borders, driver, path_to_data, countlog_folder, TRAVERSAL_WINDOW_IDX, LIGHT_ON_TIME_START, LIGHT_OFF_TIME_START, PIXEL_LENGTH_MM, CHOICEZONE_WIDTH_MM, WINDOW_SIZE, ZONE_WIDTH, jitter)
#    1039 illum_epochs = [a for a in temp_fly_df.PatternState.unique()
#    1040                 if a != 'BASELINE' and a != 'INTER-EPOCH']
#    1041 temp_fly_df_reindexed = temp_fly_df.set_index('PatternState')
# -> 1042 all_illum_data = temp_fly_df_reindexed.loc[illum_epochs]
#    1044 ## TEMPORARILY REMOVED - overall speed ratio
#    1045 # all_speeds = get_chunk_speeds_by_illumination(all_illum_data, PIXEL_LENGTH_MM)
#    1046 # res['speed_in_light'] = np.mean(all_speeds['speed_chunks_in_light'])
#    (...)
#    1069 #     res['speed_in_dark'] = np.divide(fly_in_dark.cX_smoothed_diff.abs().sum(),
#    1070 #                                      fly_in_dark.seconds_diff.sum())
#    1072 res['total_distance_window_mm'] = fly_win.cX_smoothed_diff.abs().sum()
#
# File c:\Users\user\anaconda3\envs\20250930version\lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\user\anaconda3\envs\20250930version\lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File c:\Users\user\anaconda3\envs\20250930version\lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File c:\Users\user\anaconda3\envs\20250930version\lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File c:\Users\user\anaconda3\envs\20250930version\lib\site-packages\pandas\core\indexes\base.py:6198, in Index._get_indexer_strict(self, key, axis_name)
#    6196     keyarr = self.reindex(keyarr)[0]
#    6197 else:
# -> 6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#
# File c:\Users\user\anaconda3\envs\20250930version\lib\site-packages\pandas\core\indexes\base.py:4474, in Index._reindex_non_unique(self, target)
#    4472 indexer, missing = self.get_indexer_non_unique(target)
#    4473 check = indexer != -1
# -> 4474 new_labels: Index | np.ndarray = self.take(indexer[check])
#    4475 new_indexer = None
#    4477 if len(missing):
#
# File c:\Users\user\anaconda3\envs\20250930version\lib\site-packages\pandas\core\indexes\base.py:1146, in Index.take(self, indices, axis, allow_fill, fill_value, **kwargs)
#    1108     return result
#    1110 _index_shared_docs[
#    1111     "take"
#    1112 ] = """
#    (...)
#    1143     Index(['c', 'c', 'b', 'c'], dtype='object')
#    1144     """
# -> 1146 @Appender(_index_shared_docs["take"] % _index_doc_kwargs)
#    1147 def take(
#    1148     self,
#    1149     indices,
#    1150     axis: Axis = 0,
#    1151     allow_fill: bool = True,
#    1152     fill_value=None,
#    1153     **kwargs,
#    1154 ) -> Self:
#    1155     if kwargs:
#    1156         nv.validate_take((), kwargs)
#
# KeyboardInterrupt:

# %%
#to create compiled dfs if already have single dfs
responders = ["Chrimson2", 'ACR']

for responder in responders:
    multipledf = pd.DataFrame()
    dir1 = specifiedpath + "ACC Lab Dropbox\\ACC Lab\\Nicole Lee\\Data Compilation\\osar_compiled\\2025collection\\"
    files2 = os.listdir(dir1)

    for j in files2:
        if responder in j:
            print(j)
            df=pd.read_csv(dir1 + j)
            multipledf = pd.concat([multipledf, df], axis =0)
    multipledf.to_csv(specifiedpath + "ACC Lab Dropbox\\ACC Lab\\Nicole Lee\\Data Compilation\\osar_compiled\\" + date + "_" + responder +"_totalcompilation.csv")

    print("File compiled! " + responder)
# Out:
# MB018B x Chrimson2.csv
# MB077B x Chrimson2.csv
# MB082C x Chrimson2.csv
# MB093C x Chrimson2.csv
# MB112C x Chrimson2.csv
# MB210B x Chrimson2.csv
# MB242A x Chrimson2.csv
# MB310C x Chrimson2.csv
# MB319C x Chrimson2.csv
# MB323B x Chrimson2.csv
# MB434B x Chrimson2.csv
# R76B09 x Chrimson2.csv
# SS01188 x Chrimson2.csv
# SS01194 x Chrimson2.csv
# SS01298 x Chrimson2.csv
# SS01308 x Chrimson2.csv
# SS46348 x Chrimson2.csv
# SS52050 x Chrimson2.csv
# SS67662 x Chrimson2.csv
# SS67741 x Chrimson2.csv
# SS75199 x Chrimson2.csv
# SS75200 x Chrimson2.csv
# SS77383 x Chrimson2.csv
# SS77442 x Chrimson2.csv
# SS77450 x Chrimson2.csv
# SS80896 x Chrimson2.csv
# SS80958 x Chrimson2.csv
# SS81353 x Chrimson2.csv
# SS81521 x Chrimson2.csv
# SS86947 x Chrimson2.csv
# SS95118 x Chrimson2.csv
# VT999036 x Chrimson2.csv
# File compiled! Chrimson2
# MB018B x ACR.csv
# MB077B x ACR.csv
# MB082C x ACR.csv
# MB093C x ACR.csv
# MB112C x ACR.csv
# MB242A x ACR.csv
# MB310C x ACR.csv
# MB319C x ACR.csv
# MB323B x ACR.csv
# MB434B x ACR.csv
# R76B09 x ACR.csv
# SS01188 x ACR.csv
# SS01298 x ACR.csv
# SS01308 x ACR.csv
# SS46348 x ACR.csv
# SS52050 x ACR.csv
# SS67662 x ACR.csv
# SS67741 x ACR.csv
# SS75200 x ACR.csv
# SS77383 x ACR.csv
# SS77442 x ACR.csv
# SS77450 x ACR.csv
# SS80896 x ACR.csv
# SS80958 x ACR.csv
# SS81353 x ACR.csv
# SS81521 x ACR.csv
# SS95118 x ACR.csv
# VT999036 x ACR.csv
# File compiled! ACR
