# %%
#import relevant libraries
#Load modules
import os
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import seaborn as sbs
import dabest
from datetime import datetime
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
from tqdm import tqdm
from time import sleep
import plotly.graph_objects as go
from scipy.signal import find_peaks
from numpy import genfromtxt
from scipy import fftpack
import scipy.stats as stats
import scipy 
from struct import *
import math
import osar
import sys
import glob
import scipy as sp
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import re
import warnings
date = datetime.today().strftime('%Y%m%d')

warnings.simplefilter(action="ignore", category=RuntimeWarning)
warnings.simplefilter(action="ignore", category=FutureWarning)
#warnings.simplefilter(action="default", category=RuntimeWarning)

# %%
 #SHOULD USE to generate specific genotype
officecomp = "C:\\Users\\Star\\"
labcomp = "C:\\Users\\User\\"
computer2 = "C:\\Users\\lnico\\"
homecomp = "D:\\"
specifiedpath = homecomp

root = specifiedpath + "ACC Lab Dropbox\\ACC Lab\\Nicole Lee\\DATA\\OSAR\\"

# %%
#single or list of files
startdir = 
["MB011B x ACR", "MB011B x Chrimson2", "MB018B x ACR", "MB018B x Chrimson2", 
 "MB027B x ACR", "MB027B x Chrimson2", "MB077B x ACR", "MB077B x Chrimson2", "MB080C x ACR", "MB080C x Chrimson2", 
 "MB082C x ACR", "MB083C x ACR", "MB083C x Chrimson2", "MB093C x ACR", "MB112C x ACR", "MB112C x Chrimson2", "MB210B x ACR", 
 "MB210B x Chrimson2", "MB242A x ACR", "MB323B x ACR", "MB323B x Chrimson2", "MB399B x ACR", "MB399B x Chrimson2", "MB434B x Chrimson2", 
 "MB542B x ACR", "MB542B x Chrimson2", "MB543B x ACR", "MB543B x Chrimson2", "SS01188 x ACR", "SS01188 x Chrimson2", "SS01194 x ACR", 
 "SS01194 x Chrimson2", "SS01298 x ACR", "SS01298 x Chrimson2", "SS01308 x ACR", "SS01308 x Chrimson2", "SS01337 x ACR", 
 "SS01337 x Chrimson2", "SS01388 x Chrimson2", "SS52050 x Chrimson2", "SS67662 x Chrimson2", "SS67727 x ACR", "SS67727 x Chrimson2", 
 "SS67741 x ACR", "SS67741 x Chrimson2", "SS75200 x Chrimson2", "SS76094 x ACR", "SS76094 x Chrimson2", "SS77424 x ACR", "SS77424 x Chrimson2", 
 "SS77442 x ACR", "SS77442 x Chrimson2", "SS80896 x ACR", "SS80896 x Chrimson2", "SS80958 x ACR", "SS80958 x Chrimson2", "SS80974 x ACR", 
 "SS80974 x Chrimson2", "SS81353 x ACR", "SS81353 x Chrimson2", "SS81521 x ACR", "SS81521 x Chrimson2", "SS86947 x ACR", 
 "SS86947 x Chrimson2", "SS95118 x ACR", "SS95118 x Chrimson2", "SS97567 x ACR", "SS97567 x Chrimson2", "VT999036 x ACR"]

baseDirectory=[]
basegenotype=[]
for n,sd in enumerate(startdir):
    dir1 = os.path.join(root, sd)
    baseDirectory.append(dir1)
    print(dir1)
    basegenotype.append(re.search(r'^.*?(?= x )', (os.path.split(dir1)[1])).group(0))
    #basegenotype.append(re.search(r'^.*?(?=-Gal4)', (os.path.split(dir1)[1])).group(0))
# Out:
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB399B x ACR
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB011B x Chrimson2

# %%
# all files at once (ONLY IF U PLAN TO RUN ALL AT ONCE)
startdir = os.listdir(root)
files_with_x = [f for f in startdir if 'x' in f]

baseDirectory=[]
basegenotype=[]
for n,sd in enumerate(files_with_x):
    dir1 = os.path.join(root, files_with_x[n])
    baseDirectory.append(dir1)
    print(dir1)
    basegenotype.append(re.search(r'^.*?(?= x )', (os.path.split(dir1)[1])).group(0))
    #basegenotype.append(re.search(r'^.*?(?=-Gal4)', (os.path.split(dir1)[1])).group(0))
# Out:
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB018B x ACR
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB018B x Chrimson2
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB077B x ACR
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB077B x Chrimson2
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB082C x ACR
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB082C x Chrimson2
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB093C x ACR
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB093C x Chrimson2
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB112C x ACR
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB112C x Chrimson2
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB210B x ACR
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB210B x Chrimson2
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB242A x ACR
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB242A x Chrimson2
# D:\ACC Lab Dropbox\ACC Lab\Nicole Lee\DATA\OSAR\MB310C x ACR
# ...

# %%
for loc,name in zip(baseDirectory,basegenotype):
    df = osar.osar(loc,driver = name).results
    transgenicname = loc.split("\\")[-1]
    filepath = specifiedpath + "ACC Lab Dropbox\\ACC Lab\\Nicole Lee\\Data Compilation\\osar_compiled\\2025collection\\" + transgenicname + ".csv"
    df.to_csv(filepath)
    print(name)
# Out:
# Creating borders for each fly...
# Done.
#
# Processing CSV 12 of 12
# Summarising results for all flies...
# All done.
# MB399B
# Creating borders for each fly...
# Done.
#
# Processing CSV 17 of 17
# Summarising results for all flies...
# All done.
# MB011B

# %%
#to create compiled dfs if already have single dfs
responders = ["Chrimson2", 'ACR']

for responder in responders:
    multipledf = pd.DataFrame()
    dir1 = specifiedpath + "ACC Lab Dropbox\\ACC Lab\\Nicole Lee\\Data Compilation\\osar_compiled\\2025collection\\"
    files2 = os.listdir(dir1)

    for j in files2:
        if responder in j:
            print(j)
            df=pd.read_csv(dir1 + j)
            multipledf = pd.concat([multipledf, df], axis =0)
    multipledf.to_csv(specifiedpath + "ACC Lab Dropbox\\ACC Lab\\Nicole Lee\\Data Compilation\\osar_compiled\\" + date + "_" + responder +"_totalcompilation.csv")

    print("File compiled!")
# Out:
# MB011B x Chrimson2.csv
# MB018B x Chrimson2.csv
# MB077B x Chrimson2.csv
# MB080C x Chrimson2.csv
# MB082C x Chrimson2.csv
# MB083C x Chrimson2.csv
# MB093C x Chrimson2.csv
# MB112C x Chrimson2.csv
# MB210B x Chrimson2.csv
# MB242A x Chrimson2.csv
# MB310C x Chrimson2.csv
# MB319C x Chrimson2.csv
# MB323B x Chrimson2.csv
# MB434B x Chrimson2.csv
# MB542B x Chrimson2.csv
# R76B09 x Chrimson2.csv
# SS01188 x Chrimson2.csv
# SS01194 x Chrimson2.csv
# SS01298 x Chrimson2.csv
# SS01308 x Chrimson2.csv
# SS01337 x Chrimson2.csv
# SS46348 x Chrimson2.csv
# SS52050 x Chrimson2.csv
# SS67662 x Chrimson2.csv
# SS67741 x Chrimson2.csv
# SS75199 x Chrimson2.csv
# SS75200 x Chrimson2.csv
# SS76094 x Chrimson2.csv
# SS77383 x Chrimson2.csv
# SS77424 x Chrimson2.csv
# SS77442 x Chrimson2.csv
# SS77450 x Chrimson2.csv
# SS80896 x Chrimson2.csv
# SS80958 x Chrimson2.csv
# SS80974 x Chrimson2.csv
# SS81353 x Chrimson2.csv
# SS81521 x Chrimson2.csv
# SS86947 x Chrimson2.csv
# SS95118 x Chrimson2.csv
# ...
